# %% [markdown]
# # Color restoration training on Kaggle
# Attach a clean-image Kaggle dataset, enable GPU, then update the paths below.

# %%
# %cd /kaggle/working/old_photo_restoration_2
# !pip install -q kornia lpips

# %%
# !python scripts/generate_color_dataset.py --clean-dir /kaggle/input/clean-images --output-dir data/processed/ds-color-restoration-320-v001 --overwrite

# %%
# !python scripts/train_restoration.py --config configs/color_restoration.yaml --run-id color-unet-rgb-r001-s42 --dry-run
# !python scripts/train_restoration.py --config configs/color_restoration.yaml --run-id color-unet-rgb-r001-s42

# %%
# !python scripts/evaluate_color_restoration.py --checkpoint checkpoints/color_restoration/color-unet-rgb-r001-s42/best.pth --dataset-root data/processed/ds-color-restoration-320-v001 --output-dir outputs/color_eval
